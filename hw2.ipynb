# %%
import scipy 
from scipy import misc 
import numpy as np
from matplotlib import pyplot as plt
from skimage.data import astronaut

# %%
img = astronaut()
plt.figure()
plt.imshow(img)
print('The shape of the image is: {}'.format(np.shape(img)))
# Out:
# The shape of the image is: (512, 512, 3)

# %%
def rgb2gray(img):
    R = img[:,:,0]
    G = img[:,:,1]
    B = img[:,:,2]  
    L = R*0.2989+G*0.5870+B*0.1140
    return L

plt.figure()
plt.imshow(rgb2gray(img), cmap='gray')

print('The shape of the gray image is: {} '.format(np.shape(img_gray)))
# Out:
# The shape of the gray image is: (512, 512, 3)
